# %%
import requests
from bs4 import BeautifulSoup

# %%
url = requests.get("https://www.dreamspon.com/scholarship/list.html")

soup = BeautifulSoup(url.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge ,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <title>장학금의 모든 것, 드림스폰</title>
# <meta content="장학금의 모든 것, 드림스폰" id="fa_title" property="og:title"/>
# <meta content="드림스폰" id="fa_site_name" property="og:site_name"/>
# <meta content="website" id="fa_type" property="og:type"/>
# <meta content="https://www.dreamspon.com/scholarship/list.html" id="fa_url" property="og:url"/>
# <meta content="https://www.dreamspon.com/web/images/og_image.jpg" id="fa_image" property="og:image"/>
# <meta content="대학생 필수 사이트. 외부 장학금 정보 3,000개와 공모전 정보 실시간 제공" id="fa_description" property="og:description"/>
# <meta content="대학생 필수 사이트. 외부 장학금 정보 3,000개와 공모전 정보 실시간 제공" name="description"/>
# ...

# %%
td = soup.find_all("td")

# %%
td
# Out:
# [<td class="td_subject">
#  <p class="title"><a href="/scholarship/view.html?idx=5870">경산시 학자금대출 이자지원 (2022년)</a></p>
#  <div class="hashtag">
#  <span>#대출지원</span>
#  <span>#대학생</span>
#  <span>#전문대</span>
#  </div>
#  </td>,
#  <td>경산시</td>,
#  <td class="td_day">
#  <span class="count"><span style="color:#404040;">D-0</span></span>
#  <span class="state bgRed2">마감임박</span>
#  </td>,
#  <td class="hit">103</td>,
#  <td class="td_subject">
#  <p class="title"><a href="/scholarship/view.html?idx=5874">한국외대 재직동문교수회 장학</a></p>
#  <div class="hashtag">
#  <span>#장학금</span>
#  <span>#대학생</span>
#  <span>#대학원생</span>
#  </div>
#  </td>,
#  <td>한국외대 재직동문교수회</td>,
#  <td class="td_day">
#  <span class="count"><span style="color:#404040;">D-1</span></span>
#  <span class="state bgRed2">마감임박</span>
#  </td>,
#  <td class="hit">219</td>,
#  <td class="td_subject">
#  <p class="title"><a href="/scholarship/view.html?idx=5875">안성시 청년일자리 사업</a></p>
#  <div class="hashtag">
#  <span>#근로장학</span>
# ...

# %%
p = soup.find_all('p')

# %%
p[0].text.strip()
# Out:
# '경산시 학자금대출 이자지원 (2022년)'

# %%
p[1].text.strip()
# Out:
# '한국외대 재직동문교수회 장학'

# %%
data = []
for i in p:
    data.append(i.text.strip())
data
# Out:
# ['경산시 학자금대출 이자지원 (2022년)',
#  '한국외대 재직동문교수회 장학',
#  '안성시 청년일자리 사업',
#  '고양시 장애인 일자리사업',
#  '충남 한뿌리 장학',
#  '숲과나눔 인재양성장학 (2023년)',
#  '경원장학재단 장학 (2022년)',
#  '원장재단 장학 (2022년)',
#  '녹산학술장학재단 장학 (2022년)',
#  '남양주 장애인 꿈사다리 장학금',
#  '관정이종환 장학 (2023년)',
#  '문화누리카드 신청',
#  '첫번째 장학금 받는 꿀팁 1',
#  '남해 청년 도서구입비 지원',
#  '남양주시 온라인 취업지원 컨설팅',
#  '빌라노 주식회사\n대표 : 안성규\n개인정보책임자 : 김우현\n사업자등록번호 : 134-87-09606',
#  '서울특별시 동대문구 답십리로38길 19 동대문구사회적경제허브센터 2층 드림스폰\n\nTel. 02-967-0528\nE-mail. partner@dreamspon.com\n운영시간 : 평일 09시 ~ 17시',
#  'Tel. 02-967-0528\nE-mail. partner@dreamspon.com\n운영시간 : 평일 09시 ~ 17시',
#  'Copyright © 2021 dreamspon All right reserved.']

# %%
data = list(map(lambda x: x.text.strip(), p))
data
# Out:
# ['경산시 학자금대출 이자지원 (2022년)',
#  '한국외대 재직동문교수회 장학',
#  '안성시 청년일자리 사업',
#  '고양시 장애인 일자리사업',
#  '충남 한뿌리 장학',
#  '숲과나눔 인재양성장학 (2023년)',
#  '경원장학재단 장학 (2022년)',
#  '원장재단 장학 (2022년)',
#  '녹산학술장학재단 장학 (2022년)',
#  '남양주 장애인 꿈사다리 장학금',
#  '관정이종환 장학 (2023년)',
#  '문화누리카드 신청',
#  '첫번째 장학금 받는 꿀팁 1',
#  '남해 청년 도서구입비 지원',
#  '남양주시 온라인 취업지원 컨설팅',
#  '빌라노 주식회사\n대표 : 안성규\n개인정보책임자 : 김우현\n사업자등록번호 : 134-87-09606',
#  '서울특별시 동대문구 답십리로38길 19 동대문구사회적경제허브센터 2층 드림스폰\n\nTel. 02-967-0528\nE-mail. partner@dreamspon.com\n운영시간 : 평일 09시 ~ 17시',
#  'Tel. 02-967-0528\nE-mail. partner@dreamspon.com\n운영시간 : 평일 09시 ~ 17시',
#  'Copyright © 2021 dreamspon All right reserved.']

# %%
url1 = requests.get("https://www.mk.co.kr/news/economy/")

# %%
soup1 = BeautifulSoup(url1.content, "html.parser")

# %%
soup1
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1270" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="No-Cache" http-equiv="Pragma"/>
# <title>경제 홈 - 매일경제</title>
# <meta content="경제정책, 경기지표, 무역, 세금, 외환, 은행, 보험, 카드 등 경제 뉴스 제공" property="description"/>
# <meta content="경제 홈 - 매일경제" property="og:title"/>
# <meta content="경제정책, 경기지표, 무역, 세금, 외환, 은행, 보험, 카드 등 경제 뉴스 제공" property="og:description"/>
# <meta content="https://static.mk.co.kr/facebook_mknews.jpg" property="og:image"/>
# <meta content="https://www.mk.co.kr/news/economy" property="og:url"/>
# <meta content="경제 홈 - 매일경제" property="twitter:title"/>
# ...

# %%
p1 = soup1.find_all('p')

# %%
data1 = [n.text.strip() for n in p1]
data1
# Out:
# ['2022-11-22 17:39:54',
#  '2022-11-22 17:48:49',
#  '2022-11-22 15:54:37',
#  '2022-11-22 17:25:32',
#  '매일경제 애그테크혁신센터는 21일 나주에 있는 전남 농업기술원에서 농업기술원을 비롯해 한국데이터거래소(kdx), 맘테크와 함께 ‘농업 메타버스 구축을 위한 업무협약(mou)’을 체결했다.\n4개 기관은 이를 위해 △정보, 기술 및 노하우의 상호교환 △인적 자원의 교류 및 교육 △공동사업 발굴 △공동행사 개최 △공동사업 등에 대한 홍보 △국내외 자료조사 △신규..',
#  '2022-11-23 08:51:31',
#  '우리은행이 매일 1만보 이상 걸으면 최고 연 11%를 제공하는 ‘데일리 워킹 적금’을 12월 7일 선보인다고 22일 밝혔다.\n우리은행 관계자는 “매일 걷는 일상 속에서 건강과 도전 그리고 재미를 동시에 느낄 수 있는 상품을 기획했다”고 말했다.\n이 적금은 22일부터 시작하는 사전모집을 통해 접수한 10만명에 한해 가입할 수 있다.1일 최대 적립 가능 금액은..',
#  '2022-11-23 08:39:54',
#  '하루 하루 등락을 번복하는 미국 뉴욕증시가 이번에는 상승 마감했습니다.\n매출과 조정 eps 모두 각각 월가 전망치(147억달러, 0.84달러)를 넘겼습니다.\n비용 축소형 긴축 경영에 나서겠다는 건데 hp의 방침은 최근 pc 수요가 둔화된 데 따른 반응입니다.',
#  '2022-11-23 07:44:09',
#  '내년 증여분부터는 양도소득세 회피를 방지하기 위한 이월과세와 부당행위계산 기한이 5년에서 10년으로 확대·적용될 것으로 보인다.\n시행 시점은 내년 1월1일로 돼 있다.\n22일 국회 기획재정위원회 조세소위원회에서 여야는 이 같은 내용에 잠정 합의했다.',
#  '2022-11-22 22:16:07',
# ...

# %%
soup1.find('h1').text.strip()
# Out:
# '매일 경제'

# %%
att = soup1.find('body', attrs = {'span':'경제'})

# %%
print(att)
# Out:
# None

# %%
soup1.find('li', class = 'nav')
# Out:
#   File "C:\Users\qwekl\AppData\Local\Temp\ipykernel_9044\4127734927.py", line 1
#     soup1.find('li', class = 'nav')
#                      ^
# SyntaxError: invalid syntax

# %%
cl = soup1.find_all('li')

# %%
cl
# Out:
# [<li class="nav_item"><a class="nav_link active" ga-evnt-act="section:GNB" ga-evnt-ctg="page:D-뉴스-경제-홈" ga-evnt-idx="뉴스" href="//www.mk.co.kr/"><span>뉴스</span></a></li>,
#  <li class="nav_item"><a class="nav_link" ga-evnt-act="section:GNB" ga-evnt-ctg="page:D-뉴스-경제-홈" ga-evnt-idx="프리미엄" href="https://www.mk.co.kr/premium/"><span>프리미엄</span></a></li>,
#  <li class="nav_item"><a class="nav_link" ga-evnt-act="section:GNB" ga-evnt-ctg="page:D-뉴스-경제-홈" ga-evnt-idx="연예" href="https://www.mk.co.kr/star/"><span>연예</span></a></li>,
#  <li class="nav_item"><a class="nav_link" ga-evnt-act="section:GNB" ga-evnt-ctg="page:D-뉴스-경제-홈" ga-evnt-idx="증권" href="https://vip.mk.co.kr"><span>증권</span></a></li>,
#  <li class="nav_item"><a class="nav_link" ga-evnt-act="section:GNB" ga-evnt-ctg="page:D-뉴스-경제-홈" ga-evnt-idx="부동산" href="https://www.mk.co.kr/estate/"><span>부동산</span></a></li>,
# ...

# %%
cl_nt = soup1.find_all('h3', class_ = "news_ttl")

# %%
cl_nt[0].text.strip()
# Out:
# "급한 대출 갚고 카드로 버텼다…가계빚 '1870조' 사상 최대"

# %%
ttl = list(map(lambda x: x.text.strip(), cl_nt))
ttl
# Out:
# ["급한 대출 갚고 카드로 버텼다…가계빚 '1870조' 사상 최대",
#  '상경계 교수 68% "종부세 불합리"…징벌적 과세 개편 촉구',
#  'CD금리도 연 4% 돌파…대출금리 오른다',
#  '입김 세진 금융지주…책임은 덜고 권한만',
#  '매경·전남농업기술원·KDX·맘테크, 농업 메타버스 구축 MOU 체결',
#  '“하루 만보 걸으면 최고 연 11%”…우리銀 22일부터 10만명 모집',
#  '웰스파고 “달러, 내년 1분기부터 본격 하락”...뉴욕증시 상승 마감 [월가월부]',
#  '내년부터 이월과세 기한 5년→10년',
#  '작년보다 5만명 줄긴 했지만…기혼여성 17%가 경력단절',
#  '라이더 유니온 파업 예고…업계, “이번에도 영향 미비할 것”',
#  'OECD, 내년 韓성장률 1.8%로 또 낮춰',
#  '눈덩이 적자 한전, 채권 발행한도 5배로 확대',
#  '꼬리내린 애플',
#  "신한금융 '부회장' 신설 부문총괄 둬 지배력 강화",
#  '세월호처럼 ‘대장동 진실 침몰 않는다’는 이재명',
#  '빈살만의 사우디국부펀드 카카오엔터에 투자 추진',
#  '“축구 이겼어? 그럼 오늘부로 국경일”...사우디, 아르헨 꺾자 ‘통큰 결정’',
#  '“버스기사 없었으면 어쩔뻔”…불난 차 보고도 경찰은 ‘휙’ 지나갔다',
#  '“이것 하나 허용했을 뿐인데”…카타르보다 두바이가 더 신났다',
#  "신한금융 '부회장' 신설 부문총괄 둬 지배력 강화",
#  '“오늘 산 옷, 내일 입는다”...온라인 패션도 ‘빠른 배송’ 전쟁',
#  '"대학 축제때 사람 몰려 무서워"… 총학 선거 최우선 공약은 \'안전\'',
#  '푸틴, 이젠 러군까지 쓰레기 취급?…”매립장서 전사자 시신 불태워“',
#  '“이젠 세입자가 甲”…역전세난에 집값 하락까지 집주인 시름 늘어간다']

# %%
soup1.find_all('h3')
# Out:
# [<h3 class="nav_ttl">뉴스</h3>,
#  <h3 class="nav_ttl"> </h3>,
#  <h3 class="nav_ttl">프리미엄</h3>,
#  <h3 class="nav_ttl">재테크</h3>,
#  <h3 class="nav_ttl">라이프</h3>,
#  <h3 class="nav_ttl">비즈니스</h3>,
#  <h3 class="nav_ttl">캠페인</h3>,
#  <h3 class="nav_ttl">사이트맵 <i class="arrow_go"><span class="is_blind">바로가기</span></i></h3>,
#  <h3 class="ttl">최근 검색어</h3>,
#  <h3 class="news_ttl" id="text">급한 대출 갚고 카드로 버텼다…가계빚 '1870조' 사상 최대</h3>,
#  <h3 class="news_ttl" id="today_news">상경계 교수 68% "종부세 불합리"…징벌적 과세 개편 촉구</h3>,
#  <h3 class="news_ttl" id="today_news">CD금리도 연 4% 돌파…대출금리 오른다</h3>,
#  <h3 class="news_ttl" id="today_news">입김 세진 금융지주…책임은 덜고 권한만</h3>,
#  <h3 class="news_ttl">매경·전남농업기술원·KDX·맘테크, 농업 메타버스 구축 MOU 체결</h3>,
#  <h3 class="news_ttl">“하루 만보 걸으면 최고 연 11%”…우리銀 22일부터 10만명 모집</h3>,
#  <h3 class="news_ttl">웰스파고 “달러, 내년 1분기부터 본격 하락”...뉴욕증시 상승 마감 [월가월부]</h3>,
#  <h3 class="news_ttl">내년부터 이월과세 기한 5년→10년</h3>,
#  <h3 class="news_ttl">작년보다 5만명 줄긴 했지만…기혼여성 17%가 경력단절</h3>,
# ...
