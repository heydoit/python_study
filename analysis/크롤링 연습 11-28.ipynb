# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
perido = pd.date_range(start='20221126', end='20221128')
date_list = period.strftime('%Y%m%d')

for target_date in date_list:
    
    mydate = target_date
    mypage = 1
    headers = ({
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Ch"
    })
    
    
    while True:
        url = f"https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=249&sid1=102&date={mydate}&page={mypage}"
        
        res = requests.get(url, headers = headers)
        soup = bs(res.text, 'html.parser')
        result = soup.select('.list_body ul > li')
        
        if str(mypage) != soup.select_one('.paging > strong').text.strip():
            print('-----날짜 {}기준: 뉴스목록 {} 페이지를 끝으로 크롤링 완료'.format(mydate, soup.select_one('.paging > strong').text.strip()))
            break
            
            
        for count, i in enumerate(result):
            try:
                i.select('dt')[1].select_one('a').text.strip()
            except:
                print(i.select('dt')[0].select_one('a').text.strip())
                print(i.select('dt')[0].select_one('a')['href'])
            else:
                print(i.select('dt')[1].select_one('a').text.strip())
                print(i.select('dt')[1].select_one('a')['href'])
        print('--'*20)
        print(f'현재 날짜 {mydate}기준: 뉴스목록 {mypage}페이지 크롤리 완료')
        print('--'*20)
        mypage += 1
# Out:
# '대북 송금 의혹' 아태협 회장 구속
# https://n.news.naver.com/mnews/article/015/0004773841?sid=102
# 법원, 'CJ대한통운 본사 점거 농성' 택배노조 간부 3명 구속영장 기각
# https://n.news.naver.com/mnews/article/277/0005176178?sid=102
# 이태원 참사 사망자 1명 늘어 157명…"장기기증 군 장병"(종합2보)
# https://n.news.naver.com/mnews/article/421/0006452752?sid=102
# 남욱 "유동규가 경선비 20억 요구...이재명 될 줄 알았다"
# https://n.news.naver.com/mnews/article/003/0011532432?sid=102
# 순천시자원순환센터 폐기물저장소 화재…주불 진화 중
# https://n.news.naver.com/mnews/article/003/0011532425?sid=102
# '대북 송금 의혹' 아태협 회장 구속영장 발부…法 "도주 우려" [종합]
# https://n.news.naver.com/mnews/article/015/0004773837?sid=102
# '대북송금 의혹' 안부수 아태협 회장 구속
# https://n.news.naver.com/mnews/article/469/0000707155?sid=102
# 'CJ대한통운 점거' 택배노조 간부들 구속 면해…법원, 영장 기각
# https://n.news.naver.com/mnews/article/018/0005365294?sid=102
# 법원, ‘대북 송금 의혹’ 아태평화교류협회 회장 구속영장 발부
# https://n.news.naver.com/mnews/article/032/0003185744?sid=102
# 법원, '대북송금 의혹 핵심' 안부수 아태협 회장 구속영장 발부(종합)
# ...

# %%
perido = pd.date_range(start='20221126', end='20221128')
date_list = period.strftime('%Y%m%d')

for target_date in date_list:
    
    mydate = target_date
    mypage = 1
    headers = ({
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Ch"
    })

total = []
    
    while True:
        url = f"https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=249&sid1=102&date={mydate}&page={mypage}"
        
        res = requests.get(url, headers = headers)
        soup = bs(res.text, 'html.parser')
        result = soup.select('.list_body ul > li')
        
        if str(mypage) != soup.select_one('.paging > strong').text.strip():
            print('-----날짜 {}기준: 뉴스목록 {} 페이지를 끝으로 크롤링 완료'.format(mydate, soup.select_one('.paging > strong'),text.strip()))
            break
            
            
        for count, i in enumerate(result):
            try:
                i.select('dt')[1].select_one('a').text.strip()
            except:
                news_url = i.select('dt')[0].select_one('a').attrs = ['href']
            else:
                news_url = i.select('dt')[1].select_one('a').attrs = ['href']
                
            news_res = requests.get(news_url, headers = headers)
            news_soup = bs(news_res.text, 'html.parser')
            
            try:
                news_soup.select_one('.media_end_head_title h2.media_end_head_headline').text.strip()
            except:
                news_title = news_soup.select_one('.media_end_head_title h2.media_end_head_headline').text.strip()
           
            try:
                news_soup.select_one('.go_trans _article_content').text.strip()
            except:
                news_contents = news_soup.select_one('.go_trans _article_content').text.strip()
        
            print('-'*50)
            print(f'--현재날짜 {mydate} 기준: {soup.select_one('.paging > strong').text.strip()}페이지 {count+1}번째 뉴스 크롤링 완료')
            print('-'*50)
            
            total = [news_title, news_contents]
            count += 1
# Out:
#   File "C:\Users\qwekl\AppData\Local\Temp\ipykernel_12044\1254086376.py", line 14
#     while True:
#     ^
# IndentationError: unexpected indent
